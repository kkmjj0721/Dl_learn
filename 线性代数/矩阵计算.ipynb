# %% [markdown]
# 矩阵计算：

# %% [markdown]
# 这一部分主要为矩阵的求导等；

# %% [markdown]
# 在高中以及高数中所学的求导/微分方法，这里不在讲；

# %% [markdown]
# 我们来看一下将导数扩展到不可微的函数中：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 又或者是下面这个函数：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 梯度：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1、标量对标量求导，结果为标量

# %% [markdown]
# 2、标量对向量求导，结果为行向量

# %% [markdown]
# 3、向量对标量求导，结果为列向量

# %% [markdown]
# 4、向量对向量求导，结果为矩阵

# %% [markdown]
# 在纯数学中，标量对向量求导，结果形状是原向量的转置。在机器学习/深度学习等中，标量对向量求导，结果形状与原向量保持完全一致，这样才能用梯度下降公式更新参数
